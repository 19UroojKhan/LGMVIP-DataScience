# %% [markdown]
# ***Image To Pencil Sketch With Python***
#
# **LGMVIPOCTOBER : Task 4 (1.Beginner Level Task)**
#
# **Data Science Internship**
#
# **Name: UROOJ KHAN**

# %% [markdown]
# **Task 4 : Image To Pencil Sketch With Python**

# %%
import numpy as np
import cv2
from PIL import Image
from IPython.display import display

# %%
img  =  cv2.imread("/content/cat_images.jpg")
img = cv2.resize(img,(1344,837))
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
# Out:
# <PIL.Image.Image image mode=RGB size=1344x837 at 0x7F528CB65A50>

# %%
greyscale_img =  cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(greyscale_img))
# Out:
# <PIL.Image.Image image mode=L size=1344x837 at 0x7F528CA7D750>

# %%
neg_img = cv2.bitwise_not(greyscale_img)
display(Image.fromarray(neg_img))
# Out:
# <PIL.Image.Image image mode=L size=1344x837 at 0x7F528CA7DF50>

# %%
smooth_img = cv2.GaussianBlur(neg_img, (5,5), 0, 0)
display(Image.fromarray(smooth_img))
# Out:
# <PIL.Image.Image image mode=L size=1344x837 at 0x7F528CA7D710>

# %%
sketch_img = 255 - smooth_img
sketch = cv2.divide(greyscale_img, sketch_img, scale=250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=1344x837 at 0x7F528CB65D90>

# %%
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=1344x837 at 0x7F528CA7D350>
# <PIL.Image.Image image mode=L size=1344x837 at 0x7F528CA7D610>
